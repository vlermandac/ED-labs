# %% [markdown]
# # Laboratorio 1
# Estructuras de Datos
#
# Sección 2
#
# 13/03/2023
#
# Vicente Lermanda Candia
# vlermanda2018@inf.udec.cl

# %% [markdown]
# ## F.A.Q 🤔

# %% [markdown]
# Evitar estas preguntas a menos que lo hayan intentado todo:
#
# - "Mi código está bueno y no funciona y/o entrega una solución incorrecta".
#     - No está bueno, revisalo de nuevo, prueba casos bordes.

# %% [markdown]
# - "Mi código está bueno y da error de compilación".
#     - Incluiste todas las bibliotecas?, estás compilando con las flags correspondientes? (-std=c++17, -lm, -lomp, etc).

# %% [markdown]
# - "No sé donde está el error, me puedes ayudar?"
#     - Si te voy a ayudar, pero debuggear código ajeno y largo, hasta para un profesional es difícil, más aún si el error no es evidente (memory leak, typos), por lo que cuanto tiempo le puedo dedicar a esto es situacional.
#     - Para esto siempre es bueno ir probando el código a medida que se va construyendo con pequeños testings.

# %% [markdown]
# Para garantizar respuestas a sus preguntas fuera del horario del laboratorio,
# les aseguro que los miércoles si o si les responderé (otro dia es 50/50).

# %% [markdown]
# Recursos ante dudas:
# - Stackoverflow.
# - cppreference.
# - geekforgeeks.
# - w3school.
# - **ChatGPT**, **únicamente** para resolver dudas respecto a errores. Prohibido usarlo en horario de laboratorio.

# %% [markdown]
# ## C++ 👩‍💻

# %% [markdown]
# Lenguaje multiparadigma basado en C, con características extra y soporte para Programación Orientada a Objetos.

# %% [markdown]
# ### I/O

# %%
#include<iostream>

using namespace std; # mala practica en desarrolo de software

cout<<" 🎩 : Buenos días estrellitas ✨, la tierra les dice Hooola "<<endl;

# %%
# PREDICTOR DE EDAD
cout<<"Ingrese su edad: \n";
int edad;
cin>>edad;
cout<<"Tu edad es: <<edad<<" años!\n";

# %% [markdown]
# ### Manejo de memoria

# %% [markdown]
# En C++ se asigna memoria de 2 maneras:
# - Stack: se asigna en compilación. No puede ser modificada. Se elimina una vez termina la ejecución.
# - Heap: se asigna durante la ejecución. Debe ser eliminada manualmente.

# %%
int *n = new int;
int m = 2;
n = &m;
cout<<n<<endl;
delete n;

# %% [markdown]
# Dado el siguiente arreglo:

# %%
int *arr = new int[5];

# %% [markdown]
# Como puedo ingresar 6 elementos? ☹️

# %%
# Modificar lo siguiente para que no de error
for(int i = 0; i < 6; i++){
    arr[i] = i;
}

# %% [markdown]
# ### Clases

# %%
#include<vector>

vector<int> vec(10);

for(int i : vec) cout<<i<<endl;

# %% [markdown]
# Por ahora a la clase vecotr considerenlo como un arreglo dinámico mejorado.
#
# En el loop, el índice 'i' toma el rol de 'iterador', el cual también es una clase. De forma simplificada es un puntero con permisos de "solo lectura".

# %% [markdown]
# ## Ejercicio 🧚‍♀️✨

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# James McGill, también conocido como Saul Goodman, abogado y estafador profesional está haciendo de las suyas en el club social de Albuquerque.
# "Piensa en un número entre 1 y 1000" Dijo.
# "el sabe que
